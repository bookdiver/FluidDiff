# %%
from phi.torch.flow import *
from phi.field import *

# %%
noise = Noise((batch(n_exp=3)), scale=0.15, smoothness=1.0)

# %%
u = CenteredGrid(
        noise,
        extrapolation.BOUNDARY,
        x=96,
        y=96,
        bounds=Box(x=1.0, y=1.0)
)

# %%
plot(u, show_color_bar=False)
